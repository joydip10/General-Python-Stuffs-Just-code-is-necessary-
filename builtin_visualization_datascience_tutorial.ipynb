# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
import seaborn as sns

# %%
df1=pd.read_csv(r'C:\Users\JOY STARK\Desktop\Datasets\shift_lag_codebasics\shift_lag.csv')
df1.head()
# Out:
#         Date   Price
# 0  15-Aug-17  171.00
# 1  16-Aug-17  170.00
# 2  17-Aug-17  166.91
# 3  18-Aug-17  167.41
# 4  21-Aug-17  167.78

# %%
df1.Price.plot.hist(bins=2)

# %%
df1.Price.plot(kind='hist',bins=2)

# %%
df1.Price.plot.hist()

# %%
df1.plot.area(alpha=0.4)

# %%
df1.Price.plot.bar(stacked=True)

# %%
df2=pd.read_csv(r'C:\Users\JOY STARK\Desktop\Datasets\salaries\salaries.csv')
df2
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %%
df2.plot.line(x='OtherPay',y='BasePay')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-c7e7a627eb17> in <module>
# ----> 1 df2.plot.line(x='OtherPay',y='BasePay',data=df2)
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwds)
#    3004             >>> lines = df.plot.line(x='pig', y='horse')
#    3005         """
# -> 3006         return self(kind='line', x=x, y=y, **kwds)
#    3007
#    3008     def bar(self, x=None, y=None, **kwds):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
# ...

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm') #c -> colors the plot cc. to another column
df1.plot.scatter(x='A',y='B',s=df1['C']*100,)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'A'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-04a2d66fa3fa> in <module>
# ----> 1 df1.plot.scatter(x='A',y='B',c='C')
#
# ...

# %%
df1.plot.box()

# %%
df=pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])
df.head()
# Out:
#           a         b
# 0  1.030464  1.358976
# 1 -2.360002  0.204085
# 2 -0.596135 -1.863041
# 3 -1.286522  0.540046
# 4  0.694230 -0.862037

# %%
df.plot(kind='hexbin',x='a',y='b',gridsize=25,cmap='coolwarm')

# %%
df1.plot.density()
